# %% [markdown]
# # Feature Engineering
#
# ### Whatever you do wih features, we call it as Feature Engineering.
#
# * Feature Elimination dropping the features.
#
# * Feature Addition adding some features.
#
# * Feature Transformation - transforming the given feature values into an another scale - Log Tranformation, Sqrt Transformation...
#
# * Feature Selection - deciding which features are important out of many features and choosing that features for model building.

# %% [markdown]
# ### feature selection techniques
# * sklearn - select from model
# * sklearn - RFE(i.e.Recursive feature elimination)

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,confusion_matrix,recall_score
from sklearn.feature_selection import RFE,SelectFromModel
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2 import datasets

# %%
breast_cancer=load_breast_cancer()
breast_cancer_data_df=pd.DataFrame(data=breast_cancer.data,columns=breast_cancer.feature_names)
breast_cancer_data_df["target"]=breast_cancer.target
breast_cancer_data_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# # 3 data understanding

# %%
breast_cancer_data_df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
breast_cancer_data_df.dtypes
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# ...

# %%
breast_cancer_data_df.shape
# Out:
# (569, 31)

# %% [markdown]
# # 4 data preparation

# %%
X=breast_cancer_data_df.drop("target",axis=1)
std_scaler=StandardScaler()
scaled_x=pd.DataFrame(std_scaler.fit_transform(X),columns=breast_cancer.feature_names)

# %%
y=breast_cancer_data_df.target

# %%
X_train.shape,y_train.shape
# Out:
# ((455, 30), (455,))

# %%
X_test.shape,y_test.shape
# Out:
# ((114, 30), (114,))

# %% [markdown]
# # 5 model building

# %%
X_train,X_test,y_train,y_test=train_test_split(scaled_x,y, test_size=0.20,random_state=123,shuffle=True,stratify=y,)

# %%
X_train.shape,y_train.shape
# Out:
# ((455, 30), (455,))

# %%
X_test.shape,y_test.shape
# Out:
# ((114, 30), (114,))

# %% [markdown]
# # 6 model trainig\\ 7 model testing\\ 8 model evaluation

# %%
rf_model=RandomForestClassifier(max_depth=7)
rf_model.fit(X_train,y_train)

y_pred_test=rf_model.predict(X_test)

print("Accuracy score:",round(accuracy_score(y_test,y_pred_test),4))
print("precisison_score:",round(precision_score(y_test,y_pred_test),4))
print("recall_score:",round(recall_score(y_test,y_pred_test),4))
print("confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))
# Out:
# Accuracy score: 0.9649
# precisison_score: 0.9857
# recall_score: 0.9583
# confusion_matrix:
#  [[41  1]
#  [ 3 69]]

# %%
rf_model.feature_importances_
# Out:
# array([0.02540028, 0.02217061, 0.04174051, 0.04925269, 0.00660698,
#        0.00732733, 0.05782779, 0.08209962, 0.00466839, 0.00646433,
#        0.01919118, 0.00590831, 0.01528994, 0.05377476, 0.00559294,
#        0.00480025, 0.00746643, 0.00322517, 0.004182  , 0.00483348,
#        0.07059958, 0.0169416 , 0.13030899, 0.15949769, 0.01110856,
#        0.01824941, 0.02206035, 0.12310556, 0.0114218 , 0.00888345])

# %%
select_from_model=SelectFromModel(estimator=RandomForestClassifier(), max_features=None,)
select_from_model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
breast_cancer.feature_names[select_from_model.get_support()]
# Out:
# array(['mean radius', 'mean perimeter', 'mean area',
#        'mean concave points', 'worst radius', 'worst perimeter',
#        'worst area', 'worst concave points'], dtype='<U23')

# %%
len(breast_cancer.feature_names[select_from_model.get_support()])
# Out:
# 8

# %%
X_train_select_from_model=select_from_model.transform(X_train)
X_test_select_from_model=select_from_model.transform(X_test)

# %%
X_train_select_from_model.shape,X_test_select_from_model.shape
# Out:
# ((455, 8), (114, 8))

# %%
def runRandomForestClassifier(X_train,X_test,y_train,y_test):

    rf_model=RandomForestClassifier(max_depth=7,  random_state=123,)
    rf_model.fit(X_train,y_train)
    
    y_pred_test=rf_model.predict(X_test)
    
    print("Accuracy score:",round(accuracy_score(y_test,y_pred_test),4))
    print("precisison_score:",round(precision_score(y_test,y_pred_test),4))
    print("recall_score:",round(recall_score(y_test,y_pred_test),4))
    print("confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
# %%time
runRandomForestClassifier(X_train,X_test,y_train,y_test)#30 features
# Out:
# Accuracy score: 0.9649
# precisison_score: 0.9722
# recall_score: 0.9722
# confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 266 ms
# Wall time: 257 ms

# %%
# %%time
runRandomForestClassifier(X_train_select_from_model,X_test_select_from_model,y_train,y_test)# 11 features
# Out:
# Accuracy score: 0.9474
# precisison_score: 0.9714
# recall_score: 0.9444
# confusion_matrix:
#  [[40  2]
#  [ 4 68]]
# CPU times: total: 188 ms
# Wall time: 187 ms

# %% [markdown]
# # rfe RECURSIVE FEATURE TECHNIQUES

# %%
rfe_model=RFE(estimator=RandomForestClassifier(),n_features_to_select=12,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([ True,  True,  True,  True, False, False,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True, False, False,  True,
#         True, False, False])

# %%
len(breast_cancer.feature_names[rfe_model.get_support()])
# Out:
# 12

# %%
X_train_rfe_model=rfe_model.transform(X_train)
X_test_rfe_model=rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(X_train,X_test,y_train,y_test)#30 features
# Out:
# Accuracy score: 0.9649
# precisison_score: 0.9722
# recall_score: 0.9722
# confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 219 ms
# Wall time: 239 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)# 12 features
# Out:
# Accuracy score: 0.9737
# precisison_score: 0.9859
# recall_score: 0.9722
# confusion_matrix:
#  [[41  1]
#  [ 2 70]]
# CPU times: total: 188 ms
# Wall time: 190 ms

# %% [markdown]
# # 3.take important features from the Gradient boosting and train it within randomforest algorithm

# %%
rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=12,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True, False,
#        False,  True,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True,  True,  True, False,  True,
#         True, False, False])

# %%
len(breast_cancer.feature_names[rfe_model.get_support()])
# Out:
# 12

# %%
X_train_rfe_model=rfe_model.transform(X_train)
X_test_rfe_model=rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(X_train,X_test,y_train,y_test)#30 features
# Out:
# Accuracy score: 0.9649
# precisison_score: 0.9722
# recall_score: 0.9722
# confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 281 ms
# Wall time: 300 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)# 12 features
# Out:
# Accuracy score: 0.9737
# precisison_score: 0.9859
# recall_score: 0.9722
# confusion_matrix:
#  [[41  1]
#  [ 2 70]]
# CPU times: total: 203 ms
# Wall time: 199 ms

# %% [markdown]
# # 4. how to choose the optimal number of features to train my model?

# %%
def runRandomForestClassifier(X_train,X_test,y_train,y_test):

    rf_model=RandomForestClassifier(max_depth=7,  random_state=123,)
    rf_model.fit(X_train,y_train)
    
    y_pred_test=rf_model.predict(X_test)
    
    print("Accuracy score:",round(accuracy_score(y_test,y_pred_test),4))
    print("precisison_score:",round(precision_score(y_test,y_pred_test),4))
    print("recall_score:",round(recall_score(y_test,y_pred_test),4))
    print("confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
for i in range (1,31):
    rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=i,)
    rfe_model.fit(X_train,y_train)
    X_train_rfe_model=rfe_model.transform(X_train)
    X_test_rfe_model=rfe_model.transform(X_test)
    print("select features:",i)
    runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
# Out:
# select features: 1
# Accuracy score: 0.886
# precisison_score: 0.9041
# recall_score: 0.9167
# confusion_matrix:
#  [[35  7]
#  [ 6 66]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# select features: 2
# Accuracy score: 0.9123
# precisison_score: 0.9189
# recall_score: 0.9444
# confusion_matrix:
#  [[36  6]
#  [ 4 68]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# select features: 3
# Accuracy score: 0.9561
# precisison_score: 0.9718
# recall_score: 0.9583
# confusion_matrix:
#  [[40  2]
#  [ 3 69]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# select features: 4
# Accuracy score: 0.9474
# precisison_score: 0.9714
# recall_score: 0.9444
# confusion_matrix:
#  [[40  2]
#  [ 4 68]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# select features: 5
# Accuracy score: 0.9649
# precisison_score: 0.9722
# recall_score: 0.9722
# confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# select features: 6
# Accuracy score: 0.9561
# precisison_score: 0.9718
# recall_score: 0.9583
# ...

# %% [markdown]
# # we found 20 is the number of features

# %%
rfe_model=RFE(estimator=GradientBoostingClassifier(),n_features_to_select=20,)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=20)

# %%
rfe_model.get_support()
# Out:
# array([False,  True, False, False, False,  True,  True,  True,  True,
#        False,  True,  True, False,  True,  True, False, False,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True])

# %%
(breast_cancer.feature_names[rfe_model.get_support()])
# Out:
# array(['mean texture', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'radius error',
#        'texture error', 'area error', 'smoothness error',
#        'concave points error', 'fractal dimension error', 'worst radius',
#        'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst fractal dimension'], dtype='<U23')

# %%
len(breast_cancer.feature_names[rfe_model.get_support()])
# Out:
# 20

# %%
X_train_rfe_model=rfe_model.transform(X_train)
X_test_rfe_model=rfe_model.transform(X_test)

# %%
X_train_rfe_model.shape,X_test_rfe_model.shape
# Out:
# ((455, 20), (114, 20))

# %%
# %%time
runRandomForestClassifier(X_train,X_test,y_train,y_test)#30 features
# Out:
# Accuracy score: 0.9649
# precisison_score: 0.9722
# recall_score: 0.9722
# confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 266 ms
# Wall time: 240 ms

# %%
# %%time
runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)# 12 features
# Out:
# Accuracy score: 0.9737
# precisison_score: 1.0
# recall_score: 0.9583
# confusion_matrix:
#  [[42  0]
#  [ 3 69]]
# CPU times: total: 219 ms
# Wall time: 212 ms
